# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

# %%
primary = pd.read_csv('primary_results.csv', sep = ',')
counties = pd.read_csv('county_facts.csv', sep = ',')

# %%
primary.tail()
counties.tail()
# Out:
#        fips          area_name state_abbreviation  PST045214  PST040210  \
# 3190  56037  Sweetwater County                 WY      45010      43806
# 3191  56039       Teton County                 WY      22930      21294
# 3192  56041       Uinta County                 WY      20904      21118
# 3193  56043    Washakie County                 WY       8322       8533
# 3194  56045      Weston County                 WY       7201       7208
#
#       PST120214  POP010210  AGE135214  AGE295214  AGE775214  ...  SBO415207  \
# 3190        2.7      43806        7.3       27.0        9.5  ...        3.8
# 3191        7.7      21294        5.7       19.1       12.2  ...        3.3
# 3192       -1.0      21118        7.6       29.8       11.0  ...        2.2
# 3193       -2.5       8533        5.5       23.9       20.1  ...        0.0
# 3194       -0.1       7208        6.5       21.6       18.1  ...        0.0
#
#       SBO015207  MAN450207  WTN220207  RTN130207  RTN131207  AFN120207  \
# ...

# %%
primary.shape
counties.shape
# Out:
# (3195, 54)

# %%
primary.columns
counties.columns
# Out:
# Index(['fips', 'area_name', 'state_abbreviation', 'PST045214', 'PST040210',
#        'PST120214', 'POP010210', 'AGE135214', 'AGE295214', 'AGE775214',
#        'SEX255214', 'RHI125214', 'RHI225214', 'RHI325214', 'RHI425214',
#        'RHI525214', 'RHI625214', 'RHI725214', 'RHI825214', 'POP715213',
#        'POP645213', 'POP815213', 'EDU635213', 'EDU685213', 'VET605213',
#        'LFE305213', 'HSG010214', 'HSG445213', 'HSG096213', 'HSG495213',
#        'HSD410213', 'HSD310213', 'INC910213', 'INC110213', 'PVY020213',
#        'BZA010213', 'BZA110213', 'BZA115213', 'NES010213', 'SBO001207',
#        'SBO315207', 'SBO115207', 'SBO215207', 'SBO515207', 'SBO415207',
#        'SBO015207', 'MAN450207', 'WTN220207', 'RTN130207', 'RTN131207',
#        'AFN120207', 'BPS030214', 'LND110210', 'POP060210'],
#       dtype='object')

# %%
primary['candidate'].unique()
# Out:
# array(['Donald Trump', 'Ted Cruz', 'Marco Rubio', 'Ben Carson',
#        'John Kasich', 'Hillary Clinton', 'Bernie Sanders',
#        'Carly Fiorina', 'Rand Paul', 'Mike Huckabee', 'Rick Santorum',
#        'Jeb Bush', 'Chris Christie', "Martin O'Malley", ' Uncommitted',
#        ' No Preference'], dtype=object)

# %%
primary.groupby('candidate')['votes'].sum()
# Out:
# candidate
#  No Preference         313
#  Uncommitted            43
# Ben Carson          528463
# Bernie Sanders     4740278
# Carly Fiorina        15181
# Chris Christie       24347
# Donald Trump       6944654
# Hillary Clinton    7178257
# Jeb Bush             94394
# John Kasich        2456406
# Marco Rubio        2998335
# Martin O'Malley        747
# Mike Huckabee         3300
# Rand Paul             8460
# Rick Santorum         1773
# Ted Cruz           5248807
# Name: votes, dtype: int64

# %%
candidate_to_vote_s = primary.groupby('candidate')['votes'].sum().sort_values()
candidate_to_vote_s[:2]
# Out:
# candidate
#  Uncommitted       43
#  No Preference    313
# Name: votes, dtype: int64

# %%
candidate_to_vote_s.plot(kind='barh', fontsize=8)

# %%
primary.head()
# Out:
#      state state_abbreviation   county  fips       party     candidate  votes  \
# 0  Alabama                 AL  Autauga  1001  Republican  Donald Trump   5387
# 1  Alabama                 AL  Autauga  1001  Republican      Ted Cruz   2482
# 2  Alabama                 AL  Autauga  1001  Republican   Marco Rubio   1785
# 3  Alabama                 AL  Autauga  1001  Republican    Ben Carson   1764
# 4  Alabama                 AL  Autauga  1001  Republican   John Kasich    421
#
#    fraction_votes
# 0           0.445
# 1           0.205
# 2           0.148
# 3           0.146
# 4           0.035

# %%
state_party_votes_s = primary.groupby(['state', 'party'])['votes'].sum()
state_party_votes_s
# Out:
# state           party
# Alabama         Democrat       381810
#                 Republican     805814
# Arizona         Democrat       399097
#                 Republican     435103
# Arkansas        Democrat       207182
#                 Republican     395108
# Colorado        Democrat       121184
# Florida         Democrat      1611617
#                 Republican    2156298
# Georgia         Democrat       642420
#                 Republican    1232089
# Idaho           Democrat        23567
#                 Republican     211484
# Illinois        Democrat       658976
#                 Republican     881888
# Iowa            Democrat       139682
#                 Republican     185508
# Kentucky        Republican     225709
# Louisiana       Democrat       256849
#                 Republican     240017
# Maine           Democrat          101
# Massachusetts   Democrat        51613
#                 Republican      31517
# Michigan        Democrat      1159586
# ...

# %%
state_to_votes_s = primary.groupby('state')['votes'].sum()
state_to_votes_s
# Out:
# state
# Alabama           1187624
# Arizona            834200
# Arkansas           602290
# Colorado           121184
# Florida           3767915
# Georgia           1874509
# Idaho              235051
# Illinois          1540864
# Iowa               325190
# Kentucky           225709
# Louisiana          496866
# Maine                 101
# Massachusetts       83130
# Michigan          2387495
# Mississippi        577735
# Missouri          1031302
# Nebraska            33460
# Nevada              86815
# New Hampshire      525966
# North Carolina    2180023
# Ohio              3204172
# Oklahoma           759340
# South Carolina    1105408
# Tennessee         1197202
# Texas             4091652
# Utah               254203
# Vermont             18221
# Virginia          1496131
# Name: votes, dtype: int64

# %%
state_party_votes_s = primary.groupby(['state', 'party'])['votes'].sum()
start_party_votes_s
# Out:
# state           party
# Alabama         Democrat       381810
#                 Republican     805814
# Arizona         Democrat       399097
#                 Republican     435103
# Arkansas        Democrat       207182
#                 Republican     395108
# Colorado        Democrat       121184
# Florida         Democrat      1611617
#                 Republican    2156298
# Georgia         Democrat       642420
#                 Republican    1232089
# Idaho           Democrat        23567
#                 Republican     211484
# Illinois        Democrat       658976
#                 Republican     881888
# Iowa            Democrat       139682
#                 Republican     185508
# Kentucky        Republican     225709
# Louisiana       Democrat       256849
#                 Republican     240017
# Maine           Democrat          101
# Massachusetts   Democrat        51613
#                 Republican      31517
# Michigan        Democrat      1159586
# ...

# %%
state_to_votes_s = primary.groupby('state')['votes'].sum()
state_to_votes_s.head()
# Out:
# state
# Alabama     1187624
# Arizona      834200
# Arkansas     602290
# Colorado     121184
# Florida     3767915
# Name: votes, dtype: int64

# %%
state_party_to_vote_pcts_s = state_party_votes_s / state_to_votes_s
state_party_to_vote_pcts_s.head()
# Out:
# state     party
# Alabama   Democrat      0.321491
#           Republican    0.678509
# Arizona   Democrat      0.478419
#           Republican    0.521581
# Arkansas  Democrat      0.343990
# Name: votes, dtype: float64

# %%
state_party_to_vote_pcts_s.unstack().plot(kind='barh', fontsize=8, stacked=True)

# %%
func = lambda agg_df: agg_df.sort_values('votes', ascending=False).iloc[0]

# %%
winners = primary.groupby('fips').agg(func)
winners
# Out:
#           state state_abbreviation          county       party  \
# fips
# 1001    Alabama                 AL         Autauga  Republican
# 1003    Alabama                 AL         Baldwin  Republican
# 1005    Alabama                 AL         Barbour    Democrat
# 1007    Alabama                 AL            Bibb  Republican
# 1009    Alabama                 AL          Blount  Republican
# 1011    Alabama                 AL         Bullock    Democrat
# 1013    Alabama                 AL          Butler    Democrat
# 1015    Alabama                 AL         Calhoun  Republican
# 1017    Alabama                 AL        Chambers    Democrat
# 1019    Alabama                 AL        Cherokee  Republican
# 1021    Alabama                 AL         Chilton  Republican
# 1023    Alabama                 AL         Choctaw    Democrat
# 1025    Alabama                 AL          Clarke    Democrat
# 1027    Alabama                 AL            Clay  Republican
# ...

# %%
counties['RHI825214'].head()
# Out:
# 0    62.1
# 1    66.2
# 2    75.6
# 3    83.0
# 4    46.6
# Name: RHI825214, dtype: float64

# %%
winners_county_races = pd.merge(winners, counties[['fips', 'RHI825214']],
                               left_index = True, right_on='fips', how = 'left')
winners_county_races
# Out:
#          state state_abbreviation          county       party  \
# 2      Alabama                 AL         Autauga  Republican
# 3      Alabama                 AL         Baldwin  Republican
# 4      Alabama                 AL         Barbour    Democrat
# 5      Alabama                 AL            Bibb  Republican
# 6      Alabama                 AL          Blount  Republican
# 7      Alabama                 AL         Bullock    Democrat
# 8      Alabama                 AL          Butler    Democrat
# 9      Alabama                 AL         Calhoun  Republican
# 10     Alabama                 AL        Chambers    Democrat
# 11     Alabama                 AL        Cherokee  Republican
# 12     Alabama                 AL         Chilton  Republican
# 13     Alabama                 AL         Choctaw    Democrat
# 14     Alabama                 AL          Clarke    Democrat
# 15     Alabama                 AL            Clay  Republican
# ...

# %%
winners_county_races = winners_county_races.rename(columns = {'RHI825214' : 'white_pcts'})
winners_county_races.head()
# Out:
#      state state_abbreviation   county       party        candidate  votes  \
# 2  Alabama                 AL  Autauga  Republican     Donald Trump   5387
# 3  Alabama                 AL  Baldwin  Republican     Donald Trump  23618
# 4  Alabama                 AL  Barbour    Democrat  Hillary Clinton   2567
# 5  Alabama                 AL     Bibb  Republican     Donald Trump   1959
# 6  Alabama                 AL   Blount  Republican     Donald Trump   7390
#
#    fraction_votes  fips  white_pcts
# 2           0.445  1001        75.6
# 3           0.469  1003        83.0
# 4           0.906  1005        46.6
# 5           0.494  1007        74.5
# 6           0.487  1009        87.8

# %%
winners_county_white_pcts = winners_county_races.groupby(['party', 'candidate'])['white_pcts'].mean()
winners_county_white_pcts
# Out:
# party       candidate
# Democrat    Bernie Sanders     81.944030
#             Hillary Clinton    56.856920
# Republican  Ben Carson         81.100000
#             Donald Trump       83.235638
#             John Kasich        89.226415
#             Marco Rubio        78.883333
#             Ted Cruz           74.164665
# Name: white_pcts, dtype: float64

# %%
ax = winners_county_white_pcts.plot(kind = 'barh', fontsize=8)
ax.set_xlim([50,100])
plt.tight_layout()

# %%
total_votes = primary.pivot_table(values='votes', index= 'state', columns = 'candidate', aggfunc='sum', fill_value=0)
total_votes
# Out:
# candidate        No Preference   Uncommitted  Ben Carson  Bernie Sanders  \
# state
# Alabama                      0             0       84139           74987
# Arizona                      0             0           0          163400
# Arkansas                     0             0       23105           64514
# Colorado                     0             0           0           71928
# Florida                      0             0           0          547051
# Georgia                      0             0       78731          181760
# Idaho                        0             0           0           18550
# Illinois                     0             0           0          354344
# Iowa                         0            43       17173           69311
# Kentucky                     0             0           0               0
# Louisiana                    0             0           0           62723
# Maine                        0             0           0              61
# ...

# %%
primary.pivot_table(values='fraction_votes', index='state_abbreviation', columns = 'party', aggfunc='mean')
# Out:
# party               Democrat  Republican
# state_abbreviation
# AL                  0.476823    0.195277
# AR                  0.464784    0.191924
# AZ                  0.478433    0.283867
# CO                  0.481016         NaN
# FL                  0.469349    0.242413
# GA                  0.493525    0.196939
# IA                  0.250003    0.090857
# ID                  0.494733    0.240773
# IL                  0.489632    0.242013
# KY                       NaN    0.245298
# LA                  0.451481    0.240803
# MA                  0.331875    0.193800
# ME                  0.450000         NaN
# MI                  0.487741    0.237265
# MO                  0.489403    0.243236
# MS                  0.493563    0.243344
# NC                  0.462404    0.242886
# NE                  0.489258         NaN
# NH                  0.500000    0.125000
# NV                  0.498559    0.199047
# OH                  0.492199    0.245074
# ...

# %% [markdown]
# # refered by https://nittaku.tistory.com/132?category=725162
